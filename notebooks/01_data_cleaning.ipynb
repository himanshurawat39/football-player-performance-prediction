# %%
import pandas as pd
import numpy as np
import os
import sys

df = pd.read_csv("D:/Data Science Projects/Player Performance Prediction/data/raw/players_21.csv")
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  1992-02-05
#
#    height_cm  weight_kg nationality            club_name  ...   lwb   ldm  \
# ...

# %%
df.info()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Columns: 106 entries, sofifa_id to rb
# dtypes: float64(18), int64(44), object(44)
# memory usage: 15.3+ MB
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)

# %%
df.drop(["sofifa_id", "player_url", "long_name", "dob", "international_reputation", "work_rate", "body_type", "real_face", "player_tags", "player_traits", "team_jersey_number", "loaned_from", "joined", "contract_valid_until", "nation_position", "nation_jersey_number", "defending_marking",  "ls","st","rb","rcb","cb","lcb","lb","rwb","rdm","cdm","ldm","lwb","rm","rcm","cm","rs","lcm","lm","ram","cam","lam","rw","rf","cf","lf","lw"],axis=1,inplace=True)

# %%
df.head()
# Out:
#           short_name  age  height_cm  weight_kg nationality  \
# 0           L. Messi   33        170         72   Argentina
# 1  Cristiano Ronaldo   35        187         83    Portugal
# 2           J. Oblak   27        188         87    Slovenia
# 3     R. Lewandowski   31        184         80      Poland
# 4          Neymar Jr   28        175         68      Brazil
#
#              club_name             league_name  league_rank  overall  \
# 0         FC Barcelona  Spain Primera Division          1.0       93
# 1             Juventus         Italian Serie A          1.0       92
# 2      Atlético Madrid  Spain Primera Division          1.0       91
# 3    FC Bayern München    German 1. Bundesliga          1.0       91
# 4  Paris Saint-Germain          French Ligue 1          1.0       91
#
#    potential  ...  mentality_vision  mentality_penalties mentality_composure  \
# 0         93  ...                95                   75                  96
# ...

# %%
df.describe()
# Out:
#                 age     height_cm     weight_kg   league_rank       overall  \
# count  18944.000000  18944.000000  18944.000000  18719.000000  18944.000000
# mean      25.225823    181.190773     75.016892      1.357070     65.677787
# std        4.697354      6.825672      7.057140      0.739327      7.002278
# min       16.000000    155.000000     50.000000      1.000000     47.000000
# 25%       21.000000    176.000000     70.000000      1.000000     61.000000
# 50%       25.000000    181.000000     75.000000      1.000000     66.000000
# 75%       29.000000    186.000000     80.000000      1.000000     70.000000
# max       53.000000    206.000000    110.000000      4.000000     93.000000
#
#           potential     value_eur       wage_eur     weak_foot   skill_moves  \
# count  18944.000000  1.894400e+04   18944.000000  18944.000000  18944.000000
# mean      71.086729  2.224813e+06    8675.852513      2.936603      2.363017
# ...

# %%
df.isnull().sum().sort_values(ascending=False).head(30)
# Out:
# gk_speed              16861
# gk_diving             16861
# gk_handling           16861
# gk_positioning        16861
# gk_reflexes           16861
# gk_kicking            16861
# pace                   2083
# dribbling              2083
# physic                 2083
# passing                2083
# shooting               2083
# defending              2083
# release_clause_eur      995
# club_name               225
# league_name             225
# league_rank             225
# team_position           225
# player_positions          0
# wage_eur                  0
# weak_foot                 0
# preferred_foot            0
# overall                   0
# weight_kg                 0
# short_name                0
# nationality               0
# age                       0
# height_cm                 0
# value_eur                 0
# potential                 0
# skill_moves               0
# dtype: int64

# %%
df = df.drop(columns=[col for col in df.columns if col.startswith('gk')])

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# dribbling             2083
# physic                2083
# defending             2083
# pace                  2083
# shooting              2083
# passing               2083
# release_clause_eur     995
# club_name              225
# league_name            225
# league_rank            225
# team_position          225
# overall                  0
# height_cm                0
# age                      0
# short_name               0
# weight_kg                0
# nationality              0
# skill_moves              0
# weak_foot                0
# preferred_foot           0
# dtype: int64

# %%
cols_to_impute = ['dribbling', 'physic', 'defending', 'pace', 'shooting', 'passing']
df[cols_to_impute] = df[cols_to_impute].fillna(df[cols_to_impute].mean())

df['release_clause_eur'] = df['release_clause_eur'].fillna(df['release_clause_eur'].median())

df['value_eur'] = df['value_eur'].fillna(df['value_eur'].median())

df['club_name'] = df['club_name'].fillna('Unknown')
df['league_name'] = df['league_name'].fillna('Unknown')
df['league_rank'] = df['league_rank'].fillna(df['league_rank'].median())
df['team_position'] = df['team_position'].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   short_name                  18944 non-null  object
#  1   age                         18944 non-null  int64
#  2   height_cm                   18944 non-null  int64
#  3   weight_kg                   18944 non-null  int64
#  4   nationality                 18944 non-null  object
#  5   club_name                   18944 non-null  object
#  6   league_name                 18944 non-null  object
#  7   league_rank                 18944 non-null  float64
#  8   overall                     18944 non-null  int64
#  9   potential                   18944 non-null  int64
#  10  value_eur                   18944 non-null  int64
#  11  wage_eur                    18944 non-null  int64
#  12  player_positions            18944 non-null  object
# ...

# %%
df = df.to_csv("D:/Data Science Projects/Player Performance Prediction/data/processed/players_21_cleaned.csv")
